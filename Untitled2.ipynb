# %%
import math
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 120

# %%
E =3
alpha = 0.1
T_ = 150
mu = 0.3
b = 25
a = 20
k = 3/115.08593976760775 * 1e+8
def f_r(x):
    return -k*T_/(2*(1 - mu) * np.log(b/a)) * (np.log(b/x) + 
                                                      a**2/(b**2 - a**2) * (1 - b**2/x**2)*np.log(b/a))
def f_phi(x):
    return k*T_/(2 * (1 -mu) * np.log(b/a))*(1 - np.log(b/x) - a**2/(b**2 - a**2) *(1 + b**2/x**2)*np.log(b/a))

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(20,25,100)
plt.plot(x,f_r(x))
plt.plot(x,f_phi(x))
plt.show()

# %%
# построение графиков
plt.plot(x,f_r(x), label="f_r(x)")
plt.plot(x,f_phi(x), label="f_phi(x)")

# добавление легенды и подписей осей
plt.xlabel("r-coordinate(m)")
plt.legend()

# вывод графика
plt.show()
